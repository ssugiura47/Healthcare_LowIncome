# %%
import pandas as pd
import csv
import json
import requests
import os
import pymongo
from pymongo import MongoClient
from sqlalchemy import create_engine
from pandas.io.json import json_normalize

# %%
hci_low_income = pd.read_csv("Data/hci_low_income.csv")
hci_low_income = hci_low_income[["race_eth_name","geoname","county_name","fam_lt_lw","families","livingwage"]]
hci_low_income_clean = hci_low_income.dropna(how="any", axis = 0)
hci_low_income_clean = hci_low_income_clean.rename(columns={"race_eth_name": "race", "geoname": "geoname","county_name": "county", "fam_lt_lw":"families_below_the_living_wage", "families": "number_of_families", "livingwage": "living_wage"})
hci_low_income_clean.head()
# Out:
#          race  geoname   county  families_below_the_living_wage  \
# 9        AIAN  Alameda  Alameda                            71.0
# 10      Asian  Alameda  Alameda                          5735.0
# 11  AfricanAm  Alameda  Alameda                          1149.0
# 12     Latino  Alameda  Alameda                          9281.0
# 13      NHOPI  Alameda  Alameda                           118.0
#
#     number_of_families  living_wage
# 9                320.0        22.64
# 10             41863.0        22.64
# 11              6431.0        22.64
# 12             25776.0        22.64
# 13              1046.0        22.64

# %%
hci_low_income_clean_grouped = hci_low_income_clean.groupby(["county"]).mean().reset_index()
hci_low_income_clean_grouped["percent_of_families_below_the_living_wage"] = hci_low_income_clean_grouped["families_below_the_living_wage"]/hci_low_income_clean_grouped["number_of_families"] *100
hci_low_income_clean_grouped = hci_low_income_clean_grouped.sort_values("percent_of_families_below_the_living_wage", ascending = False)
hci_low_income_clean_grouped = hci_low_income_clean_grouped.reset_index()
del hci_low_income_clean_grouped['index']
hci_low_income_clean_grouped = hci_low_income_clean_grouped.round({'families_below_the_living_wage': 2, 'number_of_families': 2, 'living_wage':2, 'percent_of_families_below_the_living_wage':2})
# hci_low_income_clean_grouped = hci_low_income_clean_grouped.reset_index(drop=True)
hci_low_income_clean_grouped
# Out:
#              county  families_below_the_living_wage  number_of_families  \
# 0            Colusa                          266.08              524.83
# 1              Lake                          227.06              457.14
# 2             Modoc                          117.50              237.62
# 3            Plumas                          156.31              317.75
# 4            Tehama                          355.64              727.00
# 5          Imperial                          752.53             1569.94
# 6           Trinity                           73.07              153.14
# 7         Mendocino                          358.65              761.73
# 8          Siskiyou                          151.66              325.75
# 9         Del Norte                          124.60              268.90
# 10           Merced                         1008.13             2188.66
# 11           Tulare                          968.51             2103.06
# 12           Fresno                         1993.76             4364.47
# 13           Madera                          627.30             1384.13
# 14      Los Angeles                         4952.60            11074.22
# 15             Kern                         1147.29             2639.12
# 16             Yuba                          352.54              815.04
# 17         Humboldt                          300.77              699.58
# 18           Shasta                          591.31             1463.25
# 19            Butte                          549.40             1373.60
# 20         Monterey                          713.41             1787.32
# 21            Kings                          569.12             1457.81
# 22       Santa Cruz                          563.42             1460.20
# 23       Stanislaus                         1073.30             2785.42
# 24   San Bernardino                         2564.66             6781.78
# 25    Santa Barbara                          885.20             2342.18
# 26            Glenn                          215.64              575.36
# 27      San Joaquin                         1604.46             4314.17
# 28       Sacramento                         2599.58             7189.23
# 29        Riverside                         2015.41             5737.80
# 30           Sutter                          555.70             1586.20
# 31        San Diego                         2946.75             8447.76
# 32         Tuolumne                          123.03              352.77
# 33         Mariposa                          109.40              318.70
# 34             Yolo                          742.65             2271.19
# 35    San Francisco                         2594.80             7948.20
# 36             Inyo                           62.21              193.00
# 37             Napa                          482.23             1509.31
# 38           Amador                          126.50              403.28
# 39           Orange                         3219.42            10285.05
# 40  San Luis Obispo                          468.32             1498.30
# 41           Nevada                          281.04              903.81
# 42             Mono                          142.00              457.38
# 43           Solano                         1187.53             3832.53
# 44           Sonoma                          701.45             2285.58
# 45          Alameda                         2400.72             8062.14
# 46       San Benito                          329.06             1134.25
# 47          Ventura                         1403.57             4906.72
# 48           Lassen                          109.44              395.00
# 49     Contra Costa                          995.34             3940.19
# 50        Calaveras                           90.00              390.12
# 51      Santa Clara                         2058.18             8984.82
# 52        San Mateo                          688.09             3011.69
# 53            Marin                          306.07             1427.76
# 54           Sierra                           17.50               83.33
# 55        El Dorado                          381.11             1873.11
# 56           Placer                          469.27             2594.05
# 57           Alpine                            2.75               34.50
#
#     living_wage  percent_of_families_below_the_living_wage
# 0         20.80                                      50.70
# 1         21.13                                      49.67
# 2         20.55                                      49.45
# 3         21.14                                      49.19
# 4         20.34                                      48.92
# 5         20.83                                      47.93
# 6         20.37                                      47.71
# 7         21.74                                      47.08
# 8         20.27                                      46.56
# 9         20.71                                      46.34
# 10        20.49                                      46.06
# 11        19.56                                      46.05
# 12        20.79                                      45.68
# 13        20.94                                      45.32
# 14        25.05                                      44.72
# 15        20.49                                      43.47
# 16        20.23                                      43.25
# 17        21.26                                      42.99
# 18        20.70                                      40.41
# 19        20.88                                      40.00
# 20        22.88                                      39.92
# 21        20.43                                      39.04
# 22        26.79                                      38.59
# 23        21.45                                      38.53
# 24        22.76                                      37.82
# 25        23.87                                      37.79
# 26        20.10                                      37.48
# 27        21.58                                      37.19
# 28        22.25                                      36.16
# 29        22.76                                      35.13
# 30        20.23                                      35.03
# 31        24.35                                      34.88
# 32        21.66                                      34.88
# 33        21.36                                      34.33
# 34        22.35                                      32.70
# 35        27.55                                      32.65
# 36        20.43                                      32.23
# 37        24.54                                      31.95
# 38        22.44                                      31.37
# 39        26.33                                      31.30
# 40        23.14                                      31.26
# 41        22.83                                      31.09
# 42        23.16                                      31.05
# 43        23.51                                      30.99
# 44        24.21                                      30.69
# 45        24.73                                      29.78
# 46        23.45                                      29.01
# 47        25.49                                      28.61
# 48        20.99                                      27.71
# 49        24.73                                      25.26
# 50        20.87                                      23.07
# 51        25.18                                      22.91
# 52        27.55                                      22.85
# 53        27.55                                      21.44
# 54        22.29                                      21.00
# 55        22.26                                      20.35
# 56        22.26                                      18.09
# 57        21.36                                       7.97

# %%
hci_low_income_clean_grouped.to_csv("Data/cleaned_lowincome.csv", encoding="utf-8", index=False, header=True)

# %%
hci_low_income_clean_race = hci_low_income_clean.groupby(["race", "county"]).mean()
hci_low_income_clean_race["percent_of_families_below_the_living_wage"] = (hci_low_income_clean_race["families_below_the_living_wage"]/
                            hci_low_income_clean_race["number_of_families"])*100
hci_low_income_clean_race = hci_low_income_clean_race.reset_index()
hci_low_income_clean_race = hci_low_income_clean_race.round({'living_wage': 2,'percent_of_families_below_the_living_wage':2})
hci_low_income_clean_race.head()
# Out:
#    race        county  families_below_the_living_wage  number_of_families  \
# 0  AIAN       Alameda                           158.5               285.0
# 1  AIAN         Butte                            56.0                91.5
# 2  AIAN  Contra Costa                            23.0               125.5
# 3  AIAN     Del Norte                             0.0                22.0
# 4  AIAN     El Dorado                             3.5                66.0
#
#    living_wage  percent_of_families_below_the_living_wage
# 0        24.74                                      55.61
# 1        20.88                                      61.20
# 2        24.74                                      18.33
# 3        20.71                                       0.00
# 4        22.26                                       5.30

# %%
hci_low_income_clean_race.to_csv("Data/cleaned_lowincomegrouped.csv", encoding="utf-8", index=False, header=True)

# %%
#Load the dataframes to Mongo DB using a new function

def write_df_to_mongoDB(  my_df,\
                          database_name = 'mydatabasename' ,\
                          collection_name = 'mycollectionname',
                          server = 'localhost',\
                          mongodb_port = 27017,\
                          chunk_size = 100):

    client = MongoClient('localhost',int(mongodb_port))
    db = client[database_name]
    collection = db[collection_name]
    # To write
    collection.delete_many({})  # Destroy the collection
    #aux_df=aux_df.drop_duplicates(subset=None, keep='last') # To avoid repetitions
    my_list = my_df.to_dict('records')
    l =  len(my_list)
    ran = range(l)
    steps=list(ran[chunk_size::chunk_size])
    steps.append([l])

    # Insert chunks of the dataframe
    i = 0
    for j in steps:
        if type(j) != list:
            collection.insert_many(my_list[i:j]) 
        i = j

    print('Done')
    return

# %%
ca_counties = pd.read_json('Data/ca_counties.json', encoding = "ISO-8859-1")
ca_counties.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 4  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...

# %%
medically_underserved_data = json.load(open('Data/Medically_Underserved_Areas.geojson'))
medically_underserved_df = pd.DataFrame(medically_underserved_data["features"])
medically_underserved_df.head()
# Out:
#       type                                         properties  \
# 0  Feature  {'OBJECTID': 1, 'OBJECTID_1': 198, 'MuaSrcID':...
# 1  Feature  {'OBJECTID': 2, 'OBJECTID_1': 199, 'MuaSrcID':...
# 2  Feature  {'OBJECTID': 3, 'OBJECTID_1': 200, 'MuaSrcID':...
# 3  Feature  {'OBJECTID': 4, 'OBJECTID_1': 201, 'MuaSrcID':...
# 4  Feature  {'OBJECTID': 5, 'OBJECTID_1': 202, 'MuaSrcID':...
#
#                                             geometry
# 0  {'type': 'Polygon', 'coordinates': [[[-121.495...
# 1  {'type': 'Polygon', 'coordinates': [[[-121.571...
# 2  {'type': 'Polygon', 'coordinates': [[[-121.621...
# 3  {'type': 'Polygon', 'coordinates': [[[-124.316...
# 4  {'type': 'Polygon', 'coordinates': [[[-119.731...

# %%
with open('Data/medical_county.json') as json_data:
    data = json.load(json_data)
medical_county = pd.DataFrame(data['records'])
medical_county = pd.DataFrame(medical_county.rename(columns={0: 'County',1: 'Provider',2: 'Address',3: 'City',
                4: 'State',5: 'Zip',6: 'Phone',7: 'Website',8: 'Category',9: 'Type',10: 'Services',
                11: 'Latitute',12: 'Longitude',13: 'Location'}))
medical_county.head()
# Out:
#     County                              Provider  \
# 0  Alameda  Oakland Community Action Partnership
# 1  Alameda  Oakland Community Action Partnership
# 2  Alameda  Oakland Community Action Partnership
# 3  Alameda  Oakland Community Action Partnership
# 4  Alameda  Oakland Community Action Partnership
#
#                                            Address     City State    Zip  \
# 0  150 Frank H. Ogawa Plaza 4th Floor, Suite 4340   Oakland    CA  94612
# 1  150 Frank H. Ogawa Plaza 4th Floor, Suite 4340   Oakland    CA  94612
# 2  150 Frank H. Ogawa Plaza 4th Floor, Suite 4340   Oakland    CA  94612
# 3  150 Frank H. Ogawa Plaza 4th Floor, Suite 4340   Oakland    CA  94612
# 4  150 Frank H. Ogawa Plaza 4th Floor, Suite 4340   Oakland    CA  94612
#
#             Phone           Website            Category                Type  \
# 0  (510) 238-2362  www.AC-OCAP.com   Community Services  Community Services
# 1  (510) 238-2362  www.AC-OCAP.com   Community Services  Community Services
# 2  (510) 238-2362  www.AC-OCAP.com   Community Services  Community Services
# 3  (510) 238-2362  www.AC-OCAP.com   Community Services  Community Services
# 4  (510) 238-2362  www.AC-OCAP.com   Community Services  Community Services
#
#                Services            Latitute     Longitude  \
# 0  Child/Youth Services  37.805293900000002  -122.2711085
# 1    Education Services  37.805293900000002  -122.2711085
# 2    Emergency Services  37.805293900000002  -122.2711085
# 3   Employment Services  37.805293900000002  -122.2711085
# 4       Health Services  37.805293900000002  -122.2711085
#
#                              Location
# 0  (37.805293900000002, -122.2711085)
# 1  (37.805293900000002, -122.2711085)
# 2  (37.805293900000002, -122.2711085)
# 3  (37.805293900000002, -122.2711085)
# 4  (37.805293900000002, -122.2711085)

# %%
#Use above function to create a collection to MongoDB

write_df_to_mongoDB(ca_counties,\
                          database_name = 'HealthcareProject' ,\
                          collection_name = 'ca_counties',
                          server = 'localhost',\
                          mongodb_port = 27017,\
                          chunk_size = 100)
# Out:
# Done

# %%
write_df_to_mongoDB(medical_county,\
                          database_name = 'HealthcareProject' ,\
                          collection_name = 'medical_county',
                          server = 'localhost',\
                          mongodb_port = 27017,\
                          chunk_size = 10)
# Out:
# Done

# %%
write_df_to_mongoDB(medically_underserved_df,\
                          database_name = 'HealthcareProject' ,\
                          collection_name = 'medically_underserved_df',
                          server = 'localhost',\
                          mongodb_port = 27017,\
                          chunk_size = 100)
# Out:
# Done

# %%
# Upload CSV files to SQL
rds_connection_string = "admin2:12345@localhost:5432/Healthcare_LowIncome"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# CREATE TABLE low_income(
# 	County VARCHAR PRIMARY KEY,
# 	Families_Below_the_Living_Wage INT,
# 	Number_of_Families INT,
# 	Living_Wage INT,
# 	Percent_of_Families_Below_the_Living_Wage INT
# );

# %%
# CREATE TABLE low_income_race(
# 	Race VARCHAR,
# 	County VARCHAR,
# 	Families_Below_the_Living_Wage INT,
# 	Number_of_Families INT,
# 	Living_Wage INT,
# 	Percent_of_Families_Below_the_Living_Wage INT,
# 	FOREIGN KEY (County) REFERENCES low_income(County)
# );

# %%
engine.table_names()
# Out:
# ['low_income', 'low_income_race']

# %%
hci_low_income_clean_grouped.to_sql(name='low_income', con=engine, if_exists='append', index=False)

# %%
hci_low_income_clean_race.to_sql(name='low_income_race', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from low_income', con=engine).head()
# Out:
#    county  families_below_the_living_wage  number_of_families  living_wage  \
# 0  Colusa                             266                 525           21
# 1    Lake                             227                 457           21
# 2   Modoc                             118                 238           21
# 3  Plumas                             156                 318           21
# 4  Tehama                             356                 727           20
#
#    percent_of_families_below_the_living_wage
# 0                                         51
# 1                                         50
# 2                                         49
# 3                                         49
# 4                                         49

# %%
pd.read_sql_query('select * from low_income_race', con=engine).head()
# Out:
#    race        county  families_below_the_living_wage  number_of_families  \
# 0  AIAN       Alameda                             159                 285
# 1  AIAN         Butte                              56                  92
# 2  AIAN  Contra Costa                              23                 126
# 3  AIAN     Del Norte                               0                  22
# 4  AIAN     El Dorado                               4                  66
#
#    living_wage  percent_of_families_below_the_living_wage
# 0           25                                       56.0
# 1           21                                       61.0
# 2           25                                       18.0
# 3           21                                        0.0
# 4           22                                        5.0
